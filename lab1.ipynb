# %%
import pandas as pd
import numpy as np

# %%
import sys
# !{sys.executable} -m pip install kagglehub[pandas-datasets]

# %%
import os
# List the contents of the downloaded dataset directory to find the correct file name
dataset_dir = '/kaggle/input/boston-housing-dataset'
if os.path.exists(dataset_dir):
    print(f"Contents of {dataset_dir}:")
    for item in os.listdir(dataset_dir):
        print(item)
else:
    print(f"Directory {dataset_dir} does not exist.")
# Out:
# Contents of /kaggle/input/boston-housing-dataset:
# BostonHousing.csv

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "BostonHousing.csv"

# Load the latest version
df = kagglehub.dataset_load(
  KaggleDatasetAdapter.PANDAS,
  "arunjangir245/boston-housing-dataset",
  file_path
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# Using Colab cache for faster access to the 'boston-housing-dataset' dataset.
# First 5 records:       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       501 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
median_value=df['rm'].median()
print(median_value)
df['rm'].fillna(median_value, inplace=True)
# Out:
# 6.208
# /tmp/ipykernel_3626/3849315560.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rm'].fillna(median_value, inplace=True)

# %%
print('statistical summary:\n')
print(df.describe())
# Out:
# statistical summary:
#
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.283587
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702126
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.618750
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
print('check missing values:\n')
print(df.isnull().sum())
# Out:
# check missing values:
#
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
print(df.columns.tolist())
# Out:
# ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat', 'medv']

# %%
df['medv'].unique()
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 13.6, 19.6, 15.2, 14.5,
#        15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 13.2, 13.1, 13.5, 20. ,
#        24.7, 30.8, 34.9, 26.6, 25.3, 21.2, 19.3, 14.4, 19.4, 19.7, 20.5,
#        25. , 23.4, 35.4, 31.6, 23.3, 18.7, 16. , 22.2, 33. , 23.5, 22. ,
#        17.4, 20.9, 24.2, 22.8, 24.1, 21.4, 20.8, 20.3, 28. , 23.9, 24.8,
#        22.5, 23.6, 22.6, 20.6, 28.4, 38.7, 43.8, 33.2, 27.5, 26.5, 18.6,
#        20.1, 19.5, 19.8, 18.8, 18.5, 18.3, 19.2, 17.3, 15.7, 16.2, 18. ,
#        14.3, 23. , 18.1, 17.1, 13.3, 17.8, 14. , 13.4, 11.8, 13.8, 14.6,
#        15.4, 21.5, 15.3, 17. , 41.3, 24.3, 27. , 50. , 22.7, 23.8, 22.3,
#        19.1, 29.4, 23.2, 24.6, 29.9, 37.2, 39.8, 37.9, 32.5, 26.4, 29.6,
#        32. , 29.8, 37. , 30.5, 36.4, 31.1, 29.1, 33.3, 30.3, 34.6, 32.9,
#        42.3, 48.5, 24.4, 22.4, 28.1, 23.7, 26.7, 30.1, 44.8, 37.6, 46.7,
# ...

# %%
df.drop('tax', axis=1, inplace=True)
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
from sklearn.preprocessing import StandardScaler, Binarizer, MinMaxScaler
min_max_scaler=MinMaxScaler()
df_min_max_scaled=pd.DataFrame(min_max_scaler.fit_transform(df),columns=df.columns)
df_min_max_scaled.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     0.040544    0.113636    0.391378    0.069170    0.349167    0.521668
# std      0.096679    0.233225    0.251479    0.253994    0.238431    0.134533
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000851    0.000000    0.173387    0.000000    0.131687    0.445392
# 50%      0.002812    0.000000    0.338343    0.000000    0.314815    0.507185
# 75%      0.041258    0.125000    0.646628    0.000000    0.491770    0.585888
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#               age         dis         rad     ptratio           b       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     0.676364    0.242381    0.371713    0.622929    0.898568    0.301409
# ...

# %%
standard_scaler=StandardScaler()
df_standard_scaled=pd.DataFrame(standard_scaler.fit_transform(df),columns=df.columns)
df_standard_scaled.describe()
# Out:
#                crim            zn         indus          chas           nox  \
# count  5.060000e+02  5.060000e+02  5.060000e+02  5.060000e+02  5.060000e+02
# mean  -1.123388e-16  7.898820e-17  2.106352e-16 -3.510587e-17 -1.965929e-16
# std    1.000990e+00  1.000990e+00  1.000990e+00  1.000990e+00  1.000990e+00
# min   -4.197819e-01 -4.877224e-01 -1.557842e+00 -2.725986e-01 -1.465882e+00
# 25%   -4.109696e-01 -4.877224e-01 -8.676906e-01 -2.725986e-01 -9.130288e-01
# 50%   -3.906665e-01 -4.877224e-01 -2.110985e-01 -2.725986e-01 -1.442174e-01
# 75%    7.396560e-03  4.877224e-02  1.015999e+00 -2.725986e-01  5.986790e-01
# max    9.933931e+00  3.804234e+00  2.422565e+00  3.668398e+00  2.732346e+00
#
#                  rm           age           dis           rad       ptratio  \
# count  5.060000e+02  5.060000e+02  5.060000e+02  5.060000e+02  5.060000e+02
# mean   4.037175e-16 -1.474446e-16 -8.425408e-17 -1.123388e-16 -4.212704e-16
# ...

# %%
binarizer=Binarizer(threshold=df['medv'].median())
binarizer.fit_transform(df[['medv']])
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
print(df[['medv']].head())
# Out:
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2
